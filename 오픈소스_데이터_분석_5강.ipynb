# %% [markdown]
# <a href="https://colab.research.google.com/github/h220101/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)

## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json', mode='w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

## DataFrame을 이용한 저장
df = pd.DataFrame([data])
# df.to_json('output_df.json', orient='records', indent=4, force_ascii=False)
df.to_json('output_df.json', orient='columns', indent=4, force_ascii=False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
df

## DataFrame 인덱스 출력
print(df.index)

## DataFrame 컬럼 출력
print(df.columns)

## DataFrame 행 출력
print(df.values.tolist()) #파이썬 리스트 형태
print(df.values) #NumPy array 형태

## DataFrame 값 출력
print(df.values.flatten()) #구조 없이 일렬로 나열
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv')
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv')
df.to_json('students_scores.json')

## HTML 형식으로 저장
html_table = df.to_html()
# print(html_table)
with open('students_scores.html', 'w') as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
##기상청 태풍 api 대체 실습 (csv 텍스트만 제공 -> json 리스트로 변환)
import pandas as pd
from io import StringIO
import requests

api_key = "hiiFdpmxQSyohXaZsQEsgg"

url = "https://apihub.kma.go.kr/api/typ01/url/typ_lst.php"
params = {
    "YY": 2012,
    "disp": 1,   # 쉼표 구분
    "help": 0,   # 헤더 포함
    "authKey": api_key
}

response = requests.get(url, params=params)

# CSV 텍스트 -> pandas DataFrame으로 변환
csv_data = StringIO(response.text)
df = pd.read_csv(csv_data, sep=",", engine="python", comment="#", on_bad_lines="skip")

# DataFrame -> JSON 리스트 형태로 변환
json_list = df.to_dict(orient="records")

print(json_list)
# Out:
# [{'2012': 2012, '1': 2, '2': 2, '4': 4, '201203290000': 201205220000, '201204020000': 201205280300, '파카르': '상우', 'PAKHAR': 'SANVU', '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제2호 태풍[상우(SANVU)]은 마카오에서 제출한 이름으로 산호를 의미함.', '=': '='}, {'2012': 2012, '1': 3, '2': 2, '4': 4, '201203290000': 201206010600, '201204020000': 201206060600, '파카르': '마와르', 'PAKHAR': 'MAWAR', '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제3호 태풍[마와르(MAWAR)]은 말레이시아에서 제출한 이름으로 장미를 의미함.', '=': '='}, {'2012': 2012, '1': 4, '2': 2, '4': 4, '201203290000': 201206120600, '201204020000': 201206200000, '파카르': '구촐', 'PAKHAR': 'GUCHOL', '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제4호 태풍[구촐(GUCHOL)]은 미크로네시아에서 제출한 이름으로 향신료를 의미함.', '=': '='}, {'2012': 2012, '1': 5, '2': 2, '4': 4, '201203290000': 201206171800, '201204020000': 201206202100, '파카르': '탈림', 'PAKHAR': 'TALIM', '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제5호 태풍[탈림(TALIM)]은 필리핀에서 제출한 이름으로 가장자리를 의미함.', '=': '='}, {'2012': 
# ...

# %%
json_list
# Out:
# [{'2012': 2012,
#   '1': 2,
#   '2': 2,
#   '4': 4,
#   '201203290000': 201205220000,
#   '201204020000': 201205280300,
#   '파카르': '상우',
#   'PAKHAR': 'SANVU',
#   '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제2호 태풍[상우(SANVU)]은 마카오에서 제출한 이름으로 산호를 의미함.',
#   '=': '='},
#  {'2012': 2012,
#   '1': 3,
#   '2': 2,
#   '4': 4,
#   '201203290000': 201206010600,
#   '201204020000': 201206060600,
#   '파카르': '마와르',
#   'PAKHAR': 'MAWAR',
#   '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제3호 태풍[마와르(MAWAR)]은 말레이시아에서 제출한 이름으로 장미를 의미함.',
#   '=': '='},
#  {'2012': 2012,
#   '1': 4,
#   '2': 2,
#   '4': 4,
#   '201203290000': 201206120600,
#   '201204020000': 201206200000,
#   '파카르': '구촐',
#   'PAKHAR': 'GUCHOL',
#   '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.': '제4호 태풍[구촐(GUCHOL)]은 미크로네시아에서 제출한 이름으로 향신료를 의미함.',
#   '=': '='},
#  {'2012': 2012,
#   '1': 5,
#   '2': 2,
#   '4': 4,
#   '201203290000': 201206171800,
#   '201204020000': 201206202100,
#   '파카르': '탈림',
# ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
# data = response.json()['response']['body']['items']
# print(type(data))
# print(len(data))
# print(data[0])
# df = pd.DataFrame(data)

## 기상청 태풍 api 대체 실습
data = json_list
print(df.head())

print(type(data))

print(len(data))

df = pd.DataFrame(data)

print(df.columns)

df.columns = [
    'YY', 'SEQ', 'NOW', 'EFF', 'TM_ST', 'TM_ED',
    'TYP_NAME', 'TYP_EN', 'REM', 'ETC'
]

print(df['TYP_NAME'])

df.head()
# Out:
#      YY  SEQ  NOW  EFF         TM_ST         TM_ED TYP_NAME   TYP_EN  \
# 0  2012    2    2    4  201205220000  201205280300       상우    SANVU
# 1  2012    3    2    4  201206010600  201206060600      마와르    MAWAR
# 2  2012    4    2    4  201206120600  201206200000       구촐   GUCHOL
# 3  2012    5    2    4  201206171800  201206202100       탈림    TALIM
# 4  2012    6    2    4  201206261200  201206300000      독수리  DOKSURI
#
#                                                REM ETC
# 0       제2호 태풍[상우(SANVU)]은 마카오에서 제출한 이름으로 산호를 의미함.   =
# 1    제3호 태풍[마와르(MAWAR)]은 말레이시아에서 제출한 이름으로 장미를 의미함.   =
# 2  제4호 태풍[구촐(GUCHOL)]은 미크로네시아에서 제출한 이름으로 향신료를 의미함.   =
# 3     제5호 태풍[탈림(TALIM)]은 필리핀에서 제출한 이름으로 가장자리를 의미함.   =
# 4              제6호 태풍[독수리(DOKSURI)]은 한국에서 제출한 이름임.   =
# <class 'list'>
# 24
# Index(['2012', '1', '2', '4', '201203290000', '201204020000', '파카르', 'PAKHAR',
#        '제1호 태풍[파카르(PAKHAR)]은 라오스에서 제출한 이름으로 메콩강에 서식하는 민물고기임.', '='],
#       dtype='object')
# 0       상우
# 1      마와르
# ...

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
## csv 형식 데이터 저장
df.to_csv('typhoon.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_json('typhoon.json', orient='records', indent=4, force_ascii=False)

## EXCEL 형식 데이터 저장
df.to_excel('typhoon.xlsx', index=False)

## HTML 형식 데이터 저장
df.to_html('typhoon.html')
